# %% [markdown]
# # Creating and Viewing Diffs #1

# %%
import pandas as pd

from pathlib import Path

# %%
PATH_DATA = Path('../data/test2')
PATHS = [PATH_DATA / f'{name}.csv' for name in ('v1', 'v2')]

# %%
from dacman_csv import TableDiffer, TableValuesDiff

# %%
differ = TableDiffer.from_config_py(PATH_DATA / 'config-2.py')

# %%
builder = differ.get_builder(*PATHS)
builder.data[0]
# Out:
#                 site_id measurement_date  temperature  pressure  humidity  \
# measurement_id
# 1258              Alpha       2018-04-03        103.7    1056.6     0.140
# 1482              Alpha       2018-11-16         67.1     994.6     0.314
# 1735               Echo       2018-12-05         84.8    1105.2     0.320
# 2066              Alpha       2019-01-29        105.6     958.1     0.290
# 2502               Echo       2018-06-06         60.3    1122.0     0.140
# 2926            Charlie       2019-01-04         62.1    1080.4     0.808
# 2948            Charlie       2018-09-11        106.2    1092.8     0.629
# 3639              Alpha       2019-03-15         85.8    1026.8     0.351
# 4080            Charlie       2018-09-30         90.6     889.1     0.757
# 4311              Alpha       2019-03-04         73.7    1058.0     0.132
# 4419              Bravo       2018-12-23         83.9     999.4     0.164
# 4467            Charlie       2018-11-15         69.2     894.4     0.338
# 6263              Alpha       2018-08-05         57.4    1137.8     0.006
# 6800              Alpha       2018-12-08         55.2     910.3     0.930
# 7436              Bravo       2018-07-30         53.9     842.5     0.460
# 8052              Alpha       2019-01-13         91.5     822.8     0.850
# 8674               Echo       2018-08-21         77.9     943.7       NaN
# 8982              Alpha       2018-11-26         81.2     905.0     0.218
# 9038              Delta       2018-09-09        102.4     978.8     0.212
# 9295              Alpha       2019-02-27        107.6    1167.7     0.678
#
#                                                           comment
# measurement_id
# 1258                             Donec posuere metus vitae ipsum.
# 1482            Aliquam sit amet diam in magna bibendum imperd...
# 1735                                                          NaN
# 2066                                                  Nulla nisl.
# 2502                     Cras in purus eu magna vulputate luctus.
# 2926                                                          NaN
# 2948                                                          NaN
# 3639                                                          NaN
# 4080            Donec odio justo, sollicitudin ut, suscipit a,...
# 4311                                                          NaN
# 4419                                                          NaN
# 4467                                                          NaN
# 6263                                                          NaN
# 6800                                                          NaN
# 7436            Duis bibendum. Morbi non quam nec dui luctus r...
# 8052                                                          NaN
# 8674                                                          NaN
# 8982                                                          NaN
# 9038                                                          NaN
# 9295            Cum sociis natoque penatibus et magnis dis par...

# %%
builder.build_columns(differ.comparators)
# Out:
# processing 'site_id'
# processing 'measurement_date'
# processing 'temperature'
# processing 'pressure'
# processing 'humidity'
# processing 'comment'

# %%
diff_stack = builder.get_diff_stack()
diff_stack

# %%
diff_stack['status'].stack().sort_values()[lambda d: d == 'D'].index.to_list()
# Out:
# [(2948, 'site_id'),
#  (2948, 'temperature'),
#  (2948, 'pressure'),
#  (1258, 'pressure'),
#  (2948, 'humidity'),
#  (2948, 'measurement_date')]

# %%
values_diff = TableValuesDiff(diff_stack)
values_diff.to_record()
# Out:
# {'added': [(2949, 'site_id'),
#   (2949, 'measurement_date'),
#   (2949, 'temperature'),
#   (2949, 'pressure'),
#   (2949, 'humidity')],
#  'deleted': [(2948, 'site_id'),
#   (2948, 'temperature'),
#   (2948, 'pressure'),
#   (1258, 'pressure'),
#   (2948, 'humidity'),
#   (2948, 'measurement_date')],
#  'unchanged': [(6263, 'pressure'),
#   (4419, 'pressure'),
#   (4419, 'humidity'),
#   (6800, 'pressure'),
#   (4467, 'site_id'),
#   (4467, 'measurement_date'),
#   (4467, 'temperature'),
#   (4467, 'pressure'),
#   (4467, 'humidity'),
#   (6263, 'site_id'),
#   (6800, 'temperature'),
#   (6800, 'measurement_date'),
#   (6800, 'site_id'),
#   (6263, 'measurement_date'),
#   (6263, 'temperature'),
#   (6263, 'humidity'),
#   (7436, 'temperature'),
#   (7436, 'site_id'),
#   (9295, 'pressure'),
#   (9295, 'temperature'),
#   (9295, 'measurement_date'),
#   (9038, 'pressure'),
#   (9038, 'temperature'),
#   (9038, 'measurement_date'),
#   (9038, 'site_id'),
#   (8982, 'humidity'),
#   (8982, 'pressure'),
#   (8982, 'temperature'),
#   (8982, 'measurement_date'),
#   (8982, 'site_id'),
#   (8674, 'pressure'),
#   (8674, 'temperature'),
#   (8674, 'measurement_date'),
#   (8674, 'site_id'),
#   (8052, 'humidity'),
#   (8052, 'pressure'),
#   (8052, 'temperature'),
#   (8052, 'site_id'),
#   (7436, 'comment'),
#   (7436, 'humidity'),
#   (7436, 'pressure'),
#   (4419, 'measurement_date'),
#   (7436, 'measurement_date'),
#   (6800, 'humidity'),
#   (4419, 'site_id'),
#   (1258, 'site_id'),
#   (4311, 'humidity'),
#   (2926, 'site_id'),
#   (2502, 'humidity'),
#   (2502, 'pressure'),
#   (2502, 'temperature'),
#   (2502, 'measurement_date'),
#   (2066, 'pressure'),
#   (2066, 'temperature'),
#   (2066, 'measurement_date'),
#   (2066, 'site_id'),
#   (1735, 'humidity'),
#   (1735, 'pressure'),
#   (1735, 'temperature'),
#   (1735, 'measurement_date'),
#   (1735, 'site_id'),
#   (1482, 'comment'),
#   (1482, 'humidity'),
#   (1482, 'pressure'),
#   (1482, 'temperature'),
#   (1482, 'measurement_date'),
#   (1482, 'site_id'),
#   (1258, 'humidity'),
#   (1258, 'temperature'),
#   (1258, 'measurement_date'),
#   (2926, 'measurement_date'),
#   (2926, 'temperature'),
#   (2502, 'comment'),
#   (2926, 'humidity'),
#   (4311, 'pressure'),
#   (9295, 'humidity'),
#   (4311, 'measurement_date'),
#   (4311, 'site_id'),
#   (4080, 'comment'),
#   (4080, 'humidity'),
#   (4080, 'pressure'),
#   (4080, 'temperature'),
#   (4080, 'measurement_date'),
#   (4080, 'site_id'),
#   (2926, 'pressure'),
#   (3639, 'humidity'),
#   (4311, 'temperature'),
#   (3639, 'site_id'),
#   (3639, 'pressure'),
#   (3639, 'temperature'),
#   (3639, 'measurement_date'),
#   (6800, 'comment'),
#   (4311, 'comment'),
#   (2926, 'comment'),
#   (2948, 'comment'),
#   (9038, 'comment'),
#   (4419, 'comment'),
#   (8674, 'comment'),
#   (8674, 'humidity'),
#   (8052, 'comment'),
#   (8982, 'comment'),
#   (6263, 'comment'),
#   (4467, 'comment'),
#   (1735, 'comment'),
#   (2949, 'comment'),
#   (3639, 'comment')],
#  'changed': [(8052, 'measurement_date'),
#   (2502, 'site_id'),
#   (2066, 'comment'),
#   (2066, 'humidity'),
#   (9295, 'comment'),
#   (4419, 'temperature'),
#   (1258, 'comment'),
#   (9295, 'site_id'),
#   (9038, 'humidity')],
#  '_context': {}}

# %%
diff = differ(*PATHS)
diff.to_record()
# Out:
# processing 'site_id'
# processing 'measurement_date'
# processing 'temperature'
# processing 'pressure'
# processing 'humidity'
# processing 'comment'
# {'schema': {'added': [],
#   'deleted': [],
#   'unchanged': ['site_id',
#    'measurement_date',
#    'temperature',
#    'pressure',
#    'humidity',
#    'comment'],
#   'changed': [],
#   '_context': {}},
#  'index': {'added': [2949],
#   'deleted': [2948],
#   'unchanged': [1258,
#    1482,
#    1735,
#    2066,
#    2502,
#    2926,
#    3639,
#    4080,
#    4311,
#    4419,
#    4467,
#    6263,
#    6800,
#    7436,
#    8052,
#    8674,
#    8982,
#    9038,
#    9295],
#   'changed': [],
#   '_context': {}},
#  'values': {'added': [(2949, 'site_id'),
#    (2949, 'measurement_date'),
#    (2949, 'temperature'),
#    (2949, 'pressure'),
#    (2949, 'humidity')],
#   'deleted': [(2948, 'site_id'),
#    (2948, 'temperature'),
#    (2948, 'pressure'),
#    (1258, 'pressure'),
#    (2948, 'humidity'),
#    (2948, 'measurement_date')],
#   'unchanged': [(6263, 'pressure'),
#    (4419, 'pressure'),
#    (4419, 'humidity'),
#    (6800, 'pressure'),
#    (4467, 'site_id'),
#    (4467, 'measurement_date'),
#    (4467, 'temperature'),
#    (4467, 'pressure'),
#    (4467, 'humidity'),
#    (6263, 'site_id'),
#    (6800, 'temperature'),
#    (6800, 'measurement_date'),
#    (6800, 'site_id'),
#    (6263, 'measurement_date'),
#    (6263, 'temperature'),
#    (6263, 'humidity'),
#    (7436, 'temperature'),
#    (7436, 'site_id'),
#    (9295, 'pressure'),
#    (9295, 'temperature'),
#    (9295, 'measurement_date'),
#    (9038, 'pressure'),
#    (9038, 'temperature'),
#    (9038, 'measurement_date'),
#    (9038, 'site_id'),
#    (8982, 'humidity'),
#    (8982, 'pressure'),
#    (8982, 'temperature'),
#    (8982, 'measurement_date'),
#    (8982, 'site_id'),
#    (8674, 'pressure'),
#    (8674, 'temperature'),
#    (8674, 'measurement_date'),
#    (8674, 'site_id'),
#    (8052, 'humidity'),
#    (8052, 'pressure'),
#    (8052, 'temperature'),
#    (8052, 'site_id'),
#    (7436, 'comment'),
#    (7436, 'humidity'),
#    (7436, 'pressure'),
#    (4419, 'measurement_date'),
#    (7436, 'measurement_date'),
#    (6800, 'humidity'),
#    (4419, 'site_id'),
#    (1258, 'site_id'),
#    (4311, 'humidity'),
#    (2926, 'site_id'),
#    (2502, 'humidity'),
#    (2502, 'pressure'),
#    (2502, 'temperature'),
#    (2502, 'measurement_date'),
#    (2066, 'pressure'),
#    (2066, 'temperature'),
#    (2066, 'measurement_date'),
#    (2066, 'site_id'),
#    (1735, 'humidity'),
#    (1735, 'pressure'),
#    (1735, 'temperature'),
#    (1735, 'measurement_date'),
#    (1735, 'site_id'),
#    (1482, 'comment'),
#    (1482, 'humidity'),
#    (1482, 'pressure'),
#    (1482, 'temperature'),
#    (1482, 'measurement_date'),
#    (1482, 'site_id'),
#    (1258, 'humidity'),
#    (1258, 'temperature'),
#    (1258, 'measurement_date'),
#    (2926, 'measurement_date'),
#    (2926, 'temperature'),
#    (2502, 'comment'),
#    (2926, 'humidity'),
#    (4311, 'pressure'),
#    (9295, 'humidity'),
#    (4311, 'measurement_date'),
#    (4311, 'site_id'),
#    (4080, 'comment'),
#    (4080, 'humidity'),
#    (4080, 'pressure'),
#    (4080, 'temperature'),
#    (4080, 'measurement_date'),
#    (4080, 'site_id'),
#    (2926, 'pressure'),
#    (3639, 'humidity'),
#    (4311, 'temperature'),
#    (3639, 'site_id'),
#    (3639, 'pressure'),
#    (3639, 'temperature'),
#    (3639, 'measurement_date'),
#    (6800, 'comment'),
#    (4311, 'comment'),
#    (2926, 'comment'),
#    (2948, 'comment'),
#    (9038, 'comment'),
#    (4419, 'comment'),
#    (8674, 'comment'),
#    (8674, 'humidity'),
#    (8052, 'comment'),
#    (8982, 'comment'),
#    (6263, 'comment'),
#    (4467, 'comment'),
#    (1735, 'comment'),
#    (2949, 'comment'),
#    (3639, 'comment')],
#   'changed': [(8052, 'measurement_date'),
#    (2502, 'site_id'),
#    (2066, 'comment'),
#    (2066, 'humidity'),
#    (9295, 'comment'),
#    (4419, 'temperature'),
#    (1258, 'comment'),
#    (9295, 'site_id'),
#    (9038, 'humidity')],
#   '_context': {}},
#  '_context': {'old': '../data/test2/v1.csv',
#   'new': '../data/test2/v2.csv',
#   'config': {'load_mode': 'csv',
#    'rename_fields': {'date': 'measurement_date'},
#    'process_func': <function dacman_csv.process_test2(df)>,
#    'index_fields': 'measurement_id',
#    'sort_fields': 'measurement_id',
#    'comparators': {'*': 'compare_numeric',
#     'measurement_date': 'compare_time',
#     'site_id': 'compare_eq',
#     'comment': 'compare_eq',
#     'measurement_id': 'compare_eq'}}}}

# %%
from dacman_csv import PrettyPrint, Interactive

# %%
pp = PrettyPrint(diff)
pp.backend
# Out:
# 'json'

# %%
pp
# Out:
# {
#     "schema": {
#         "added": [],
#         "deleted": [],
#         "unchanged": [
#             "site_id",
#             "measurement_date",
#             "temperature",
#             "pressure",
#             "humidity",
#             "comment"
#         ],
#         "changed": [],
#         "_context": {}
#     },
#     "index": {
#         "added": [
#             2949
#         ],
#         "deleted": [
#             2948
#         ],
#         "unchanged": [
#             1258,
#             1482,
#             1735,
#             2066,
#             2502,
#             2926,
#             3639,
#             4080,
#             4311,
#             4419,
#             4467,
#             6263,
#             6800,
#             7436,
#             8052,
#             8674,
#             8982,
#             9038,
#             9295
#         ],
#         "changed": [],
#         "_context": {}
#     },
#     "values": {
#         "added": [
#             [
#                 2949,
#                 "site_id"
#             ],
#             [
#                 2949,
#                 "measurement_date"
#             ],
#             [
#                 2949,
#                 "temperature"
#             ],
#             [
#                 2949,
#                 "pressure"
#             ],
#             [
#                 2949,
#                 "humidity"
#             ]
#         ],
#         "deleted": [
#             [
#                 2948,
#                 "site_id"
#             ],
#             [
#                 2948,
#                 "temperature"
#             ],
#             [
#                 2948,
#                 "pressure"
#             ],
#             [
#                 1258,
#                 "pressure"
#             ],
#             [
#                 2948,
#                 "humidity"
#             ],
#             [
#                 2948,
#                 "measurement_date"
#             ]
#         ],
#         "unchanged": [
#             [
#                 6263,
#                 "pressure"
#             ],
#             [
#                 4419,
#                 "pressure"
#             ],
#             [
#                 4419,
#                 "humidity"
#             ],
#             [
#                 6800,
#                 "pressure"
#             ],
#             [
#                 4467,
#                 "site_id"
#             ],
#             [
#                 4467,
#                 "measurement_date"
#             ],
#             [
#                 4467,
#                 "temperature"
#             ],
#             [
#                 4467,
#                 "pressure"
#             ],
#             [
#                 4467,
#                 "humidity"
#             ],
#             [
#                 6263,
#                 "site_id"
#             ],
#             [
#                 6800,
#                 "temperature"
#             ],
#             [
#                 6800,
#                 "measurement_date"
#             ],
#             [
#                 6800,
#                 "site_id"
#             ],
#             [
#                 6263,
#                 "measurement_date"
#             ],
#             [
#                 6263,
#                 "temperature"
#             ],
#             [
#                 6263,
#                 "humidity"
#             ],
#             [
#                 7436,
#                 "temperature"
#             ],
#             [
#                 7436,
#                 "site_id"
#             ],
#             [
#                 9295,
#                 "pressure"
#             ],
#             [
#                 9295,
#                 "temperature"
#             ],
#             [
#                 9295,
#                 "measurement_date"
#             ],
#             [
#                 9038,
#                 "pressure"
#             ],
#             [
#                 9038,
#                 "temperature"
#             ],
#             [
#                 9038,
#                 "measurement_date"
#             ],
#             [
#                 9038,
#                 "site_id"
#             ],
#             [
#                 8982,
#                 "humidity"
#             ],
#             [
#                 8982,
#                 "pressure"
#             ],
#             [
#                 8982,
#                 "temperature"
#             ],
#             [
#                 8982,
#                 "measurement_date"
#             ],
#             [
#                 8982,
#                 "site_id"
#             ],
#             [
#                 8674,
#                 "pressure"
#             ],
#             [
#                 8674,
#                 "temperature"
#             ],
#             [
#                 8674,
#                 "measurement_date"
#             ],
#             [
#                 8674,
#                 "site_id"
#             ],
#             [
#                 8052,
#                 "humidity"
#             ],
#             [
#                 8052,
#                 "pressure"
#             ],
#             [
#                 8052,
#                 "temperature"
#             ],
#             [
#                 8052,
#                 "site_id"
#             ],
#             [
#                 7436,
#                 "comment"
#             ],
#             [
#                 7436,
#                 "humidity"
#             ],
#             [
#                 7436,
#                 "pressure"
#             ],
#             [
#                 4419,
#                 "measurement_date"
#             ],
#             [
#                 7436,
#                 "measurement_date"
#             ],
#             [
#                 6800,
#                 "humidity"
#             ],
#             [
#                 4419,
#                 "site_id"
#             ],
#             [
#                 1258,
#                 "site_id"
#             ],
#             [
#                 4311,
#                 "humidity"
#             ],
#             [
#                 2926,
#                 "site_id"
#             ],
#             [
#                 2502,
#                 "humidity"
#             ],
#             [
#                 2502,
#                 "pressure"
#             ],
#             [
#                 2502,
#                 "temperature"
#             ],
#             [
#                 2502,
#                 "measurement_date"
#             ],
#             [
#                 2066,
#                 "pressure"
#             ],
#             [
#                 2066,
#                 "temperature"
#             ],
#             [
#                 2066,
#                 "measurement_date"
#             ],
#             [
#                 2066,
#                 "site_id"
#             ],
#             [
#                 1735,
#                 "humidity"
#             ],
#             [
#                 1735,
#                 "pressure"
#             ],
#             [
#                 1735,
#                 "temperature"
#             ],
#             [
#                 1735,
#                 "measurement_date"
#             ],
#             [
#                 1735,
#                 "site_id"
#             ],
#             [
#                 1482,
#                 "comment"
#             ],
#             [
#                 1482,
#                 "humidity"
#             ],
#             [
#                 1482,
#                 "pressure"
#             ],
#             [
#                 1482,
#                 "temperature"
#             ],
#             [
#                 1482,
#                 "measurement_date"
#             ],
#             [
#                 1482,
#                 "site_id"
#             ],
#             [
#                 1258,
#                 "humidity"
#             ],
#             [
#                 1258,
#                 "temperature"
#             ],
#             [
#                 1258,
#                 "measurement_date"
#             ],
#             [
#                 2926,
#                 "measurement_date"
#             ],
#             [
#                 2926,
#                 "temperature"
#             ],
#             [
#                 2502,
#                 "comment"
#             ],
#             [
#                 2926,
#                 "humidity"
#             ],
#             [
#                 4311,
#                 "pressure"
#             ],
#             [
#                 9295,
#                 "humidity"
#             ],
#             [
#                 4311,
#                 "measurement_date"
#             ],
#             [
#                 4311,
#                 "site_id"
#             ],
#             [
#                 4080,
#                 "comment"
#             ],
#             [
#                 4080,
#                 "humidity"
#             ],
#             [
#                 4080,
#                 "pressure"
#             ],
#             [
#                 4080,
#                 "temperature"
#             ],
#             [
#                 4080,
#                 "measurement_date"
#             ],
#             [
#                 4080,
#                 "site_id"
#             ],
#             [
#                 2926,
#                 "pressure"
#             ],
#             [
#                 3639,
#                 "humidity"
#             ],
#             [
#                 4311,
#                 "temperature"
#             ],
#             [
#                 3639,
#                 "site_id"
#             ],
#             [
#                 3639,
#                 "pressure"
#             ],
#             [
#                 3639,
#                 "temperature"
#             ],
#             [
#                 3639,
#                 "measurement_date"
#             ],
#             [
#                 6800,
#                 "comment"
#             ],
#             [
#                 4311,
#                 "comment"
#             ],
#             [
#                 2926,
#                 "comment"
#             ],
#             [
#                 2948,
#                 "comment"
#             ],
#             [
#                 9038,
#                 "comment"
#             ],
#             [
#                 4419,
#                 "comment"
#             ],
#             [
#                 8674,
#                 "comment"
#             ],
#             [
#                 8674,
#                 "humidity"
#             ],
#             [
#                 8052,
#                 "comment"
#             ],
#             [
#                 8982,
#                 "comment"
#             ],
#             [
#                 6263,
#                 "comment"
#             ],
#             [
#                 4467,
#                 "comment"
#             ],
#             [
#                 1735,
#                 "comment"
#             ],
#             [
#                 2949,
#                 "comment"
#             ],
#             [
#                 3639,
#                 "comment"
#             ]
#         ],
#         "changed": [
#             [
#                 8052,
#                 "measurement_date"
#             ],
#             [
#                 2502,
#                 "site_id"
#             ],
#             [
#                 2066,
#                 "comment"
#             ],
#             [
#                 2066,
#                 "humidity"
#             ],
#             [
#                 9295,
#                 "comment"
#             ],
#             [
#                 4419,
#                 "temperature"
#             ],
#             [
#                 1258,
#                 "comment"
#             ],
#             [
#                 9295,
#                 "site_id"
#             ],
#             [
#                 9038,
#                 "humidity"
#             ]
#         ],
#         "_context": {}
#     },
#     "_context": {
#         "old": "../data/test2/v1.csv",
#         "new": "../data/test2/v2.csv",
#         "config": {
#             "load_mode": "csv",
#             "rename_fields": {
#                 "date": "measurement_date"
#             },
#             "process_func": "<function process_test2 at 0x7fafe848c400>",
#             "index_fields": "measurement_id",
#             "sort_fields": "measurement_id",
#             "comparators": {
#                 "*": "compare_numeric",
#                 "measurement_date": "compare_time",
#                 "site_id": "compare_eq",
#                 "comment": "compare_eq",
#                 "measurement_id": "compare_eq"
#             }
#         }
#     }
# }

# %%
i = Interactive(diff)
i.display()
# Out:
# interactive(children=(Dropdown(description='Sort by: ', options=('site_id', 'measurement_date', 'temperature',…
