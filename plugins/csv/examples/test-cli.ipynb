# %% [markdown]
# CLI invocation

# %%
PATH_DATA="data/test1"

# %%
python dacman_csv.py $PATH_DATA/2019DacManBasic{A,B}.csv
# Out:
# {
#     "schema": {
#         "added": [
#             "Temp"
#         ],
#         "deleted": [
#             "Temperature"
#         ],
#         "unchanged": [
#             "Site",
#             "Location",
#             "Date",
#             "Pressure",
#             "Misc"
#         ],
#         "changed": [],
#         "_context": {}
#     },
#     "index": {
#         "added": [],
#         "deleted": [],
#         "unchanged": [
#             0,
#             1,
#             2,
#             3
#         ],
#         "changed": [],
#         "_context": {}
#     },
#     "records": {
#         "added": [],
#         "deleted": [],
#         "unchanged": [
#             {
#                 "Site": "B",
#                 "Location": "DF",
#                 "Date": "1/4/17",
#                 "Pressure": 9,
#                 "Misc": "dfsdfwefefds"
#             },
#             {
#                 "Site": "C",
#                 "Location": "X",
# ...

# %%
source activate dev-dacman
dacman diff $PATH_DATA/2019DacManBasic{A,B}.csv --datachange -a './dacman_csv.py'
# Out:
# (dev-dacman) WARNING:dacman.core.diff:Datapaths are not indexed. Trying to locate and index the data...
# INFO:dacman.core.diff:Starting diff calculation
# Files /home/ludo/Dropbox/lbl/deduce/csv-plugin/data/test1/2019DacManBasicB.csv and /home/ludo/Dropbox/lbl/deduce/csv-plugin/data/test1/2019DacManBasicA.csv changed
# INFO:dacman.core.diff:Using Python multiprocessing for calculating data changes in modified files
# INFO:dacman.core.diff:Calculating changes in /home/ludo/Dropbox/lbl/deduce/csv-plugin/data/test1/2019DacManBasicA.csv and /home/ludo/Dropbox/lbl/deduce/csv-plugin/data/test1/2019DacManBasicB.csv
# INFO:dacman.core.diff:Using custom executable analyzer ./dacman_csv.py
# INFO:dacman.core.diff:Change calculation completed with output:
# {
#     "schema": {
#         "added": [
#             "Temp"
#         ],
#         "deleted": [
#             "Temperature"
#         ],
#         "unchanged": [
#             "Site",
#             "Location",
#             "Date",
# ...

# %%
./dacman_csv.py $PATH_DATA/2019DacManBasic{A,B}.csv
